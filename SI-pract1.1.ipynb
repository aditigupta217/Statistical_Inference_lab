# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.worldometers.info/geography/alphabetical-list-of-countries/?s=09&utm_source=chatgpt.com$0"
response = requests.get('https://www.worldometers.info/geography/alphabetical-list-of-countries/?s=09&utm_source=chatgpt.com$0')

# %%
print(response.status_code)
# Out:
# 200

# %%
soup=(BeautifulSoup(response.content,'html.parser'))
print(BeautifulSoup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-astro-transition-scope="astro-s7reefwf-2" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    List of Countries of the world in alphabetical order (A to Z) - Worldometer
#   </title>
#   <!-- <I18nTags /> -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZDP3BFSX60">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     // eslint-disable-next-line prefer-rest-params
#     dataLayer.push(arguments);
#   }
#   gtag("js", new Date());
#   gtag("config", "G-ZDP3BFSX60", {
#     page_lang: document.documentElement.lang,
#   });
#   </script>
#   <script crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-3701697624350410">
#   </script>
# ...

# %%
print(soup.find('title'))
# Out:
# <title>List of Countries of the world in alphabetical order (A to Z) - Worldometer</title>

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="datatable w-full border border-zinc-200" data-locale="en" data-options='{"searchable":false,"sortable":false,"pageSize":false}' data-sort-col="-1" data-sort-dir="asc" id=""> <thead> <tr> <th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false"> <span>#</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false"> <span>Country</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false"> <span>Population 2026</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false" data-type="number"> <span>Land Area (Km²)</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false" data-type="number"> <span>Density (P/Km²)</span> </th> </tr> </thead> <tbody> <tr> <td class="border-e border-zinc-200 px-2 border-b py-1.5 text-start"> 1 </td><td class="border-e border-zin
# ...

# %%
print(table)
# Out:
# <table class="datatable w-full border border-zinc-200" data-locale="en" data-options='{"searchable":false,"sortable":false,"pageSize":false}' data-sort-col="-1" data-sort-dir="asc" id=""> <thead> <tr> <th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false"> <span>#</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false"> <span>Country</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false"> <span>Population 2026</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false" data-type="number"> <span>Land Area (Km²)</span> </th><th class="border-e border-zinc-200 px-2 border-b-3 py-1 font-semibold" data-sortable="false" data-type="number"> <span>Density (P/Km²)</span> </th> </tr> </thead> <tbody> <tr> <td class="border-e border-zinc-200 px-2 border-b py-1.5 text-start"> 1 </td><td class="border-e border-zin
# ...

# %%
data = []
rows = table.find_all('tr')[1:]
for row in rows:
    cols = row.find_all('td')
    values = []
    for col in cols:
      values.append(col.text)
      data.append(values)

# %%
data
# Out:
# [[' 1 ', ' Afghanistan ', ' 45,047,069 ', ' 652,860 ', ' 69 '],
#  [' 1 ', ' Afghanistan ', ' 45,047,069 ', ' 652,860 ', ' 69 '],
#  [' 1 ', ' Afghanistan ', ' 45,047,069 ', ' 652,860 ', ' 69 '],
#  [' 1 ', ' Afghanistan ', ' 45,047,069 ', ' 652,860 ', ' 69 '],
#  [' 1 ', ' Afghanistan ', ' 45,047,069 ', ' 652,860 ', ' 69 '],
#  [' 2 ', ' Albania ', ' 2,751,025 ', ' 27,400 ', ' 100 '],
#  [' 2 ', ' Albania ', ' 2,751,025 ', ' 27,400 ', ' 100 '],
#  [' 2 ', ' Albania ', ' 2,751,025 ', ' 27,400 ', ' 100 '],
#  [' 2 ', ' Albania ', ' 2,751,025 ', ' 27,400 ', ' 100 '],
#  [' 2 ', ' Albania ', ' 2,751,025 ', ' 27,400 ', ' 100 '],
#  [' 3 ', ' Algeria ', ' 48,028,334 ', ' 2,381,740 ', ' 20 '],
#  [' 3 ', ' Algeria ', ' 48,028,334 ', ' 2,381,740 ', ' 20 '],
#  [' 3 ', ' Algeria ', ' 48,028,334 ', ' 2,381,740 ', ' 20 '],
#  [' 3 ', ' Algeria ', ' 48,028,334 ', ' 2,381,740 ', ' 20 '],
#  [' 3 ', ' Algeria ', ' 48,028,334 ', ' 2,381,740 ', ' 20 '],
# ...

# %%
headers = []
for header in table.find_all('th'):
    headers.append(header.text)

# %%
pd.DataFrame(data,columns=headers)
# Out:
#         #        Country  Population 2026  Land Area (Km²)  Density (P/Km²)
# 0       1    Afghanistan       45,047,069          652,860               69
# 1       1    Afghanistan       45,047,069          652,860               69
# 2       1    Afghanistan       45,047,069          652,860               69
# 3       1    Afghanistan       45,047,069          652,860               69
# 4       1    Afghanistan       45,047,069          652,860               69
# ..     ...            ...              ...              ...              ...
# 970   195       Zimbabwe       17,273,580          386,850               45
# 971   195       Zimbabwe       17,273,580          386,850               45
# 972   195       Zimbabwe       17,273,580          386,850               45
# 973   195       Zimbabwe       17,273,580          386,850               45
# 974   195       Zimbabwe       17,273,580          386,850               45
#
# [975 rows x 5 columns]

# %%
df.to_csv('df.csv')
